# %% [markdown]
# #**August 21st, 2023**

# %% [markdown]
# #**Object-oriented programming (OOP)** is a computer programming model that organizes software design around data, or objects, rather than functions and logic. An object can be defined as a data field that has unique attributes and behavior.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
int1 = 1947
print(type(int1)) # It is creating one object int1 and class is int. It is inheriting class and taking all the properties of class.
# Out:
# <class 'int'>

# %%
flt1 = 3.1415
print(type(flt1))
# Out:
# <class 'float'>

# %%
class Audi999:
  pass

obj1 = Audi999()

# %%
print(type(obj1))
# Out:
# <class '__main__.Audi999'>

# %%
class university_student: #class
  def student_info(): #function/method....there can be creating a lot of functions
    pass # to compile code without error....use it when you're not writing code in body

# %%
obj1 = university_student()

# %%
obj1.student_info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-e8ba827e4100> in <cell line: 1>()
# ----> 1 obj1.student_info( )
#
# TypeError: university_student.student_info() takes 0 positional arguments but 1 was given

# %%
class university_student:
  def __init__(self, fname, mname, lname, gender, email, contact):
    pass

# %%
obj1  = university_student('Kin', "Zen", "Anto", 'm', 'kin.anto@firstmail.com', 9876)

# %%
print(type(obj1))
# Out:
# <class '__main__.university_student'>

# %%
class store_customer():
  def customer_name():
    pass

# %%
obj1 = store_customer()

# %%
print(type(obj1))
# Out:
# <class '__main__.store_customer'>

# %% [markdown]
# #**component of object oriented programming**
# 1) class
# 2) object
# 3) inheritance
# 4) polymorphism
# 5) abstraction
# 6) encapsulation

# %%
class university_student: # class is case-sensitive....always suggested to write in capital letter
  def __init__(self, fname, mname, lname, gender, email, contact): # default function...underscore underscore init underscore underscore...gives freedom of parameters
    pass

# %%
class university_student:
  def __init__(self, fname, mname, lname, gender, email, contact):
    self.fname = fname
    self.mname = mname
    self.lname = lname
    self.gender = gender
    self.email = email
    self.contact = contact
    print(self.fname, self.mname, self.lname, self.gender, self.email, self.contact)

# %%
obj1 = university_student('Kin', "Zen", "Anto",'m','kin.anto@firstmail.com', 9876)
# Out:
# Kin Zen Anto m kin.anto@firstmail.com 9876

# %%
class animal:
  def __init__(dg, type, breed, gender, age):
    pass

# %%
obj1 = animal ('dog', 'Pomeranian', 'f', 6)

# %%
class animal:
  def __init__ (dg, type, breed, gender, age):
    dg.type=type
    dg.breed=breed
    dg.gender=gender
    dg.age=age

  def animal (dg):
    print(dg.type, dg.breed, dg.gender,dg.age)

# %%
obj1 = animal ('dog','Pomaranian','f', 6)

# %%
obj1.animal()
# Out:
# dog Pomaranian f 6

# %%
class car:
  def __init__(self, name, model, fuel, cc, cylinders):
    self.name=name
    self.model=model
    self.fuel=fuel
    self.cc=cc
    self.cylinders=cylinders
  def car_details(self): # this is defined to print car details
    print(self.name, self.model,self.fuel,self.cc, self.cylinders)

# %%
obj1 = car('Audi777','777','Electric', 3500, 12)

# %%
obj1.car_details()
# Out:
# Audi777 777 Electric 3500 12

# %% [markdown]
# ![OOP.png](data:image/png;base64,...)

# %% [markdown]
# ![Inheritance OOP.png](data:image/png;base64,...)

# %% [markdown]
# #**#Inheritance**

# %%
#Great Grand Parent
class transportation:
	pass
#Grand Parent
class air(transportation):
	pass

class water(transportation):
	pass

class land(transportation):
	pass

#parent
class wheeler2(land):
	pass

class wheeler3(land):
	pass

class wheeler4(land):
	pass

class wheeler6(land):
	pass

class wheeler8(land):
	pass

class wheeler10(land):
	pass

class wheeler12(land):
	pass

#child
class gas(wheeler4):
	pass

class petrol(wheeler4):
	pass

class diseal(wheeler4):
	pass

class electic(wheeler4):
	pass

class battery(wheeler4):
	pass

class solar():
	pass

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class executive:
  pass

class company_services (executive):
  pass
class production (executive):
  pass
class sales (executive):
  pass


class finance(company_services):
  pass
class hr(company_services):
  pass
class inventory(production):
  pass
class assembly(production):
  pass
class maintenance(production):
  pass
class testing(production):
  pass
class RD(production):
  pass

# %% [markdown]
# #**August 22, 2023 Tuesday**

# %%
class person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print ("class person:", self.firstname, ' ', self.lastname)

# %%
obj1 = person ('Reshma', 'Sarker')

# %%
obj1.printname()
# Out:
# class person: Reshma   Sarker

# %%
class childclass(person): # childclass is inheriting from person..taking same values, variables, parameters
  pass #childclass is inheriting and this 'pass' is not stoping it anywhere

# %%
obj2 = childclass ('Abeline', 'Sarker')

# %%
obj2.printname()
# Out:
# Abeline   Sarker

# %%
class childclass(person):
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print ("class childclass(person):", self.firstname, ' ', self.lastname) # It is printing from class child

# %%
obj1 = childclass('Abeline', 'Sarker')

# %%
obj1.printname()
# Out:
# class childclass(person): Abeline   Sarker

# %%
# Alternamte way to inherite class from parent
class person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print ("class person:", self.firstname, ' ', self.lastname)

# %%
class childclass(person):
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

# %%
obj1 = childclass('Abeline', 'Sarker')

# %%
obj1.printname()
# Out:
# class person: Abeline   Sarker

# %%
# E.g.:
class animal:
  def __init__(self, type, breed age, gender):
    self.type = type
    self.breed = breed
    self.age = age
    self.gender = gender

  def printname(self):
    print ("Class animal:", self.type, ' ', self.breed, ' ', self.age, ' ', self.gender)

# %%
obj1 = animal ('Dog', 'Pomeranian', 6, 'F')

# %%
obj1.printname()
# Out:
# Class animal: Dog   Pomeranian   6   F

# %%
class childclass(animal):
  pass

# %%
obj2 = childclass ('Dog', 'Pomeranian', 2, 'M')

# %%
obj2.printname()
# Out:
# Class animal: Dog   Pomeranian   2   M

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print ("Class Person:", self.firstname, self.lastname)

# %%
class Student(Person):
  def __init__ (self, fname, lname):
    super().__init__(fname, lname) # It is running/calling the fxn from parent class due to super fxn. Super fxn helps to call parent class from child class.

# %%
obj = Student('Reshma', 'Sarker')

# %%
obj.printname()
# Out:
# Class Person: Reshma Sarker

# %%
class car:
  def __init__ (self, name, model):
    self.name = name
    self.model = model

  def print_details(self):
    print("Class car:", self.name, self.model)

# %%
class audi(car):
  def __init__ (self, name, model):
    super().__init__(name, model)

# %%
obj1 = audi('audi 777', 777)

# %%
obj1.print_details()
# Out:
# Class car: audi 777 777

# %%
class audi(car):
  def __init__ (self, name, model, make):
    super().__init__(name, model)
    self.make = 1978

  def print_details(self):
    print(self.name, self.model, self.make)

# %%
obj1 = audi('audi', 777, 1978)

# %%
obj1.print_details()
# Out:
# audi 777 1978

# %%
class school:
  def __init__ (self, name, location):
    self.name = name
    self.location = location

  def printname(self):
    print("Class school: ", self.name, self.location)

# %%
class Sumnima (school):
  def __init__ (self, name, location, built):
    super().__init__ (name, location)
    self.built = 2000

  def printname(self):
    print (self.name, self.location, self.built)

# %%
obj1 = Sumnima("Sumnima School", "Nepal", 2000)

# %%
obj1.printname()
# Out:
# Sumnima School Nepal 2000

# %% [markdown]
# #**August 23, 2023**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Single inheritance-----child is inherited from one parent

# %%
class mother:
  def __init__(self):
    pass

class father:
  def __init__(self):
    pass

class daughter(mother, father):
  def __init__(self):
    pass

class son(mother, father):
  def __init__(self):
    pass

# %%
class kitchen:
  def __init__(self):
    pass

class living_room:
  def __init__(self):
    pass

class coffee_table(kitchen, living_room):
  def __init__(self):
    pass

class chairs(kitchen, living_room):
  def __init__(self):
    pass

class glasses(kitchen, living_room):
  def __init__(self):
    pass

# %%
class school:
  def __init__ (self, name, location):
    self.name = name
    self.location = location

class university:
  def __init__ (self, name, location):
    self.name = name
    self.location = location

class Sumnima (school):
  def __init__ (self, name, location, built):
    super().__init__ (name, location)
    self.built = 2000

  def printname(self):
    print (self.name, self.location, self.built)

class Tribhuvan (university):
  def __init__ (self, name, location, built):
    super().__init__ (name, location)
    self.built = 1900

  def printname(self):
    print (self.name, self.location, self.built)

# %%
obj1 = Sumnima("Sumnima School", "Nepal", 2000)
obj2 = Tribhuvan("Tribhuvan University", "KTM", 1900)

# %%
obj1.printname()
obj2.printname()
# Out:
# Sumnima School Nepal 2000
# Tribhuvan University KTM 1900

# %%
class a:
  var_a1 = "This is my first print statement inside class a "
  def __init__(self):
    self.var_a2 = "This my second print statement inside function __init__ of class a"
    self.var_a1 = "Instance variable in class a"
    self.var_tmp1 = "This is var_tmp1 inside class a"

class b(a):
  var_b1 = "this is my third print statement inside class b "
  def __init__(self):

    self.var_b2 = "This is my fouth print statement inside function __init__ of class b"
    self.var_a1 = "Instance variable in class b"
    self.var_tmp1 = "This is var_tmp1 inside class b"
    super().__init__()

# %%
obj_a = a()
obj_b = b()

print(obj_a.var_a1)
print(obj_a.var_tmp1)
print(obj_b.var_a1)
print(obj_b.var_a2)
print(obj_b.var_b1)
print(obj_b.var_b2)
print(obj_b.var_tmp1)
# Out:
# Instance variable in class a
# This is var_tmp1 inside class a
# Instance variable in class a
# This my second print statement inside function __init__ of class a
# this is my third print statement inside class b
# This is my fouth print statement inside function __init__ of class b
# This is var_tmp1 inside class a

# %%
class fruit:
  type1 = "I love sweet fruits."
  def __init__(self):
    self.type1 = "sour_fruit"
    self.type2 = "sweet fruit"
    self.type3= "berries"

class apple (fruit):
  apple = "I love an apple. "
  def __init__(self):
    self.type1 = "Pink lady apple"
    self.type2 = "Gala apple"
    self.type3 = "Green apple"
    super().__init__()

# %%
obj1 = fruit()
obj2 = apple()

print(obj1.type1)
print(obj1.type2)
print(obj1.type3)
print(obj2.type1)
print(obj2.type2)
print(obj2.type3)
# Out:
# sour_fruit
# sweet fruit
# berries
# sour_fruit
# sweet fruit
# berries

# %% [markdown]
# #**August 24, 2023**
#
# 1. Over Loading
# 2. Over Ridding
# 3. Operator Over Loading
# 4. Polymorphism
# 5. Encapsulation

# %%
print(10 + 12)
# Out:
# 22

# %%
print(3.1415 + 3.1415)
# Out:
# 6.283

# %%
print('Python'+'Programming')
# Out:
# PythonProgramming

# %%
print([12,23,34,45] + [56,67,78,89,90])
# Out:
# [12, 23, 34, 45, 56, 67, 78, 89, 90]

# %%
l = 'Python Programming'

print(len(l))

l = [12,23,34,45,56,67,78,89,90]

print(len(l))

l = (11,22,33,44,55,66,77,88,99,110)

print(len(l))

l = {'a':'apple',
     'b':'banana',
     'c':'cherries'}

print(len(l))
# Out:
# 18
# 9
# 10
# 3

# %%
class person:  # parent class
  def __init__(self, fname, mname, lname):
    pass
  def print_details(self):
    print(self.fname, self.mname,self.lname)

class student(person):  # child class, here, the foll0wing function is over riding parent class and print from child class.
  def __init__(self, fname, mname, lname):
    pass
  def print_details(self):
    print(self.fname, self.mname,self.lname)

# %%
# Polymorphism: one function being used in different classes that gives different output
#This is an example of polymorphism, over loading and over riding.

class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self): # move function
    print("Drive!")

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!")

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car class .... # car1, boat1, plane1 are objects
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat class
plane1 = Plane("Boeing", "747")     #Create a Plane class

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %%
class vehicle:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print('move!!')

class Car(vehicle):  #inheritance is here, as child is inherited from parent
  def move(self):    #polymorphism is here, as move is used by all child and parent class
    print("Drive!")  # over-riding is here, as child class takes function of parent class and prints own object

class Boat(vehicle):
  def move(self):
    print("Sail!")

class Plane(vehicle):
  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")
boat1 = Boat("Ibiza", "Touring 20")
plane1 = Plane("Boeing", "747")

for i in (car1, boat1, plane1):
  print(i.brand) #It'll go to car1 and print ford, mustang and print from child class Drive.
  print(i.model)
  i.move()
# Out:
# Ford
# Mustang
# Drive!
# Ibiza
# Touring 20
# Sail!
# Boeing
# 747
# Fly!

# %%
class beverage:
  def __init__(self, category, brand):
    self.category = category
    self.brand = brand

  def drink(self):
    print ('drink')

class coca_cola (beverage):
  def drink(self):
    print ('coke')

class pinot_noir(beverage):
 def drink(self):
    print ('red wine')

class tropicana(beverage):
  def drink(self):
    print ('orange juice')

drink1 = coca_cola('carbonated drink', 'coca cola')
drink2 = pinot_noir('hard', 'pinot noir')
drink3 = tropicana('juice', 'tropicana')

for i in (drink1,drink2,drink3):
  print(i.category)
  print(i.brand)
  i.drink()
# Out:
# carbonated drink
# coca cola
# coke
# hard
# pinot noir
# red wine
# juice
# tropicana
# orange juice

# %% [markdown]
# #**August 25, 2023**

# %% [markdown]
# #**Encapsulation is used to restrict access to methods and variables. In encapsulation, code and data are wrapped together within a single unit from being modified by accident. Encapsulation is a mechanism of wrapping the data (variables) and code acting on the data (methods) together as a single unit.**

# %%
#Encapsulation

class transport:

  def __init__(self, brand, model, year):
    self.brandofvehicle = brand
    self.modelofvehicle = model
    self.yearofmfg = year

  def print_details(self):
    print(self.brandofvehicle, self.modelofvehicle, self.yearofmfg)

# %%
obj1 = transport('Toyota','Etios','2014')

# %%
obj1.print_details()
# Out:
# Toyota Etios 2014

# %%
#inheritance
#child class extra veriables

# %%
class fragrance:

  def __init__(self, type1, note):
    self.type1 = type1
    self.note = note

  def print_info(self):
    print(self.type1, self.note)

# %%
obj1 = fragrance('Eau de Parfum','spicy')

# %%
obj1.print_info()
# Out:
# Eau de Parfum spicy

# %%
class Students:
   def __init__(self, name, rank, points):
      self.name = name
      self.rank = rank
      self.points = points

   # custom function
   def demofunc(self):
      print("I am "+self.name)
      print("I got Rank ",+self.rank)

# create 4 objects
st1 = Students("Steve", 1, 100)
st2 = Students("Chris", 2, 90)
st3 = Students("Mark", 3, 76)
st4 = Students("Kate", 4, 60)

# call the functions using the objects created above
st1.demofunc()
st2.demofunc()
st3.demofunc()
st4.demofunc()
# Out:
# I am Steve
# I got Rank  1
# I am Chris
# I got Rank  2
# I am Mark
# I got Rank  3
# I am Kate
# I got Rank  4

# %% [markdown]
# #**Exception Handling**
#
#       1. Build-in Exception
#       2. User Define Exception

# %%
f = open('myTextFile.txt', 'x')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-22-8947e18c0489> in <cell line: 1>()
# ----> 1 f = open('myTextFile.txt', 'x')
#
# FileExistsError: [Errno 17] File exists: 'myTextFile.txt'

# %%
f = open('myTextFile1.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-869e17014e90> in <cell line: 1>()
# ----> 1 f = open('myTextFile1.txt', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myTextFile1.txt'

# %%
try:
  f = open('myTextFile1.txt', 'r')
except Exception as e:
  print('Exception ', e)

# %%
try:
  f = open('myTextFile1.txt', 'r')
except Exception as e:
  print('Exception ', e)
except FileNotFoundError as fnfe:
  print('FileNotFoundError ', fnfe)

# %%
try:
  f = open('myTextFile1.txt', 'r')
  a = 10/0
except FileNotFoundError as fnfe:
  print('FileNotFoundError ', fnfe)
except Exception as e:
  print('Exception ', e)
# Out:
# FileNotFoundError  [Errno 2] No such file or directory: 'myTextFile1.txt'

# %%
try:
  f = open('myTextFile.txt', 'r')
  a = 10/0
except FileNotFoundError as fnfe:
  print('FileNotFoundError ', fnfe)
except Exception as e:
  print('Exception ', e)
# Out:
# Exception  division by zero

# %%
try:
  f = open('myTextFile.txt', 'r')
  a = 10/0
except FileNotFoundError as fnfe:
  print('FileNotFoundError ', fnfe)
except ZeroDivisionError as zde:
  print('ZeroDivisionError ', zde)
except Exception as e:
  print('Exception ', e)
# Out:
# ZeroDivisionError  division by zero

# %%
try:
  f = open('myTextFile.txt', 'r')
  a = 10/0
except ArithmeticError as ae:
  print('ArithmeticError ', ae)
except FileNotFoundError as fnfe:
  print('FileNotFoundError ', fnfe)
except ZeroDivisionError as zde:
  print('ZeroDivisionError ', zde)
except Exception as e:
  print('Exception ', e)
# Out:
# ArithmeticError  division by zero

# %%
try:
  # f = open('myTextFile.txt', 'r')
  a = 10/0

except FileNotFoundError as fnfe:
  print('FileNotFoundError ', fnfe)
except ZeroDivisionError as zde:
  print('ZeroDivisionError ', zde)
except ArithmeticError as ae:
  print('ArithmeticError ', ae)
except Exception as e:
  print('Exception ', e)
# Out:
# ZeroDivisionError  division by zero

# %%
try:
  # f = open('myTextFile.txt', 'r')
  a = 10/0
except Exception as e:
  print('Exception ', e)
except FileNotFoundError as fnfe:
  print('FileNotFoundError ', fnfe)
except ZeroDivisionError as zde:
  print('ZeroDivisionError ', zde)
except ArithmeticError as ae:
  print('ArithmeticError ', ae)
# Out:
# Exception  division by zero

# %%
class user_define_exception1(Exception):
  pass

# %%
try:
  print('my first user define exceptopm',12/0)
except user_define_exception1 as ude1:
  print('user_define_exception1', ude1)
except Exception as e:
  print('Exception ', e)
# Out:
# Exception  division by zero

# %%
class AgeOfVoting(Exception):
  "Raise when the input is less than 18"
  pass

input_num = int(input('Enter Age '))

try:
  if input_num < 18:
    raise AgeOfVoting
  else:
    print('Eligible for voting ')

except AgeOfVoting as aov:
  print('exception as Invalid Age')
# Out:
# Enter Age 89
# Eligible for voting

# %%
try:

  #list = [1,2,3,4,5]
  #print(list[9])

  a = int(input("Name:"))
  print(a)

except SyntaxError as SE:
  print ("Syntax Error: ", SE)

except IndexError as IE:
  print ("Index Error", IE)

except ValueError as VE:
  print ("Value Error:", VE)

except Exception as E:
  print ("Exception: ", E)
# Out:
# Name:1
# 1

# %%
class zerodivision (Exception):
  pass

try:
  num = int(input("Enter a number: "))
  if num == 0:
    raise zerodivision
  else:
    print ("Accepted!!! You entered ", num, "." )
except zerodivision:
  print ("You entered zero, try again!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-928cbe8bdfca> in <cell line: 4>()
#       3
#       4 try:
# ----> 5   num = int(input("Enter a number: "))
#       6   if num == 0:
#       7     raise zerodivision
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
