# %% [markdown]
# #**September 01, 2023**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #**Python Pandas DataFrame**

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst1 = [12,23,34,45,56,67,78,89,90,110]
df1 = pd.DataFrame(lst1)
print(df1)
type(df1)
# Out:
#      0
# 0   12
# 1   23
# 2   34
# 3   45
# 4   56
# 5   67
# 6   78
# 7   89
# 8   90
# 9  110
# pandas.core.frame.DataFrame

# %%
lang = ['C','C++','Java','Python']
df2 = pd.DataFrame(lang)
df2
# Out:
#         0
# 0       C
# 1     C++
# 2    Java
# 3  Python

# %%
rating = [4,3,2,1]
df2[1] = rating
df2
# Out:
#         0  1
# 0       C  4
# 1     C++  3
# 2    Java  2
# 3  Python  1

# %%
df2.columns = ['language', 'rating']
df2
# Out:
#   language  rating
# 0        C       4
# 1      C++       3
# 2     Java       2
# 3   Python       1

# %%
lst1 = [1,5,6,7,9,50,23]
df1 = pd.DataFrame(lst1)
print(df1)
type(df1)
# Out:
#     0
# 0   1
# 1   5
# 2   6
# 3   7
# 4   9
# 5  50
# 6  23
# pandas.core.frame.DataFrame

# %%
tpl1 = (1,8,6,3,80,66,0)
df2 = pd.DataFrame(tpl1)
print(df2)
type(df2  )
# Out:
#     0
# 0   1
# 1   8
# 2   6
# 3   3
# 4  80
# 5  66
# 6   0
# pandas.core.frame.DataFrame

# %%
set1 = {'a','b',1,5,'#'}
df3 = pd.DataFrame(set1)
print(df3)
type(df3)
# Out:
#    0
# 0  1
# 1  5
# 2  b
# 3  a
# 4  #
# pandas.core.frame.DataFrame

# %%
# Create Dataframe from Dictionary
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df2 = pd.DataFrame(data)
df3 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b'])
df4 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c'])
df5 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c' , 'd'])

# %%
df2
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
df3
# Out:
#       a   b
# row1  1   2
# row2  5  10

# %%
df4
# Out:
#       a   b     c
# row1  1   2   NaN
# row2  5  10  20.0

# %%
df5
# Out:
#       a   b     c   d
# row1  1   2   NaN NaN
# row2  5  10  20.0 NaN

# %%
df6 = pd.DataFrame({'ID':[1,2,3,4], 'Name':['Ramesh','Suresh','Naresh','Sukesh']})
df6
# Out:
#    ID    Name
# 0   1  Ramesh
# 1   2  Suresh
# 2   3  Naresh
# 3   4  Sukesh

# %%
df6['ID'], df6['Name']
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  Name: ID, dtype: int64,
#  0    Ramesh
#  1    Suresh
#  2    Naresh
#  3    Sukesh
#  Name: Name, dtype: object)

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %% [markdown]
# #**Dataframe of Random Numbers with Date Indices**

# %%
dates = pd.date_range(start='01-Aug-2023', end='31-Aug-2023')

# %%
dates
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('today', periods=7)
dates
# Out:
# DatetimeIndex(['2023-10-21 19:38:40.669477', '2023-10-22 19:38:40.669477',
#                '2023-10-23 19:38:40.669477', '2023-10-24 19:38:40.669477',
#                '2023-10-25 19:38:40.669477', '2023-10-26 19:38:40.669477',
#                '2023-10-27 19:38:40.669477'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('2023-08-25', periods=7)
dates
# Out:
# DatetimeIndex(['2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
M = np.random.random((7,7))
M
# Out:
# array([[0.69734942, 0.84112668, 0.66963584, 0.0599283 , 0.04563705,
#         0.47030715, 0.96591751],
#        [0.52953376, 0.22178584, 0.20904458, 0.34423632, 0.48533192,
#         0.2042916 , 0.9712561 ],
#        [0.45626456, 0.21061876, 0.21702437, 0.71798777, 0.03011457,
#         0.05000969, 0.8231173 ],
#        [0.82600298, 0.24699434, 0.49650844, 0.04257819, 0.81436967,
#         0.8079887 , 0.86970545],
#        [0.79896115, 0.83214569, 0.6087603 , 0.57622879, 0.24723932,
#         0.53021115, 0.04837677],
#        [0.37749369, 0.1977843 , 0.91902063, 0.64090949, 0.06428807,
#         0.43293192, 0.03139048],
#        [0.89504703, 0.33903631, 0.76175772, 0.73754585, 0.61117269,
#         0.39150885, 0.25284387]])

# %%
df = pd.DataFrame(M, index=dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                    6
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.columns = ['C1','C2','C3','C4','C5','C6','C7']
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.sort_values(by='C1', ascending=True)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-30  0.031390
# 2023-08-27  0.823117
# 2023-08-26  0.971256
# 2023-08-25  0.965918
# 2023-08-29  0.048377
# 2023-08-28  0.869705
# 2023-08-31  0.252844

# %%
df.sort_values(by='C1', ascending=False)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
#
#                   C7
# 2023-08-31  0.252844
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-30  0.031390

# %%
df.sort_index(ascending=False)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
#
#                   C7
# 2023-08-31  0.252844
# 2023-08-30  0.031390
# 2023-08-29  0.048377
# 2023-08-28  0.869705
# 2023-08-27  0.823117
# 2023-08-26  0.971256
# 2023-08-25  0.965918

# %%
df.loc['2023-08-31']
# Out:
# C1    0.895047
# C2    0.339036
# C3    0.761758
# C4    0.737546
# C5    0.611173
# C6    0.391509
# C7    0.252844
# Name: 2023-08-31 00:00:00, dtype: float64

# %%
df.loc['2023-08-29':'2023-08-31']
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df['C1']
# Out:
# 2023-08-25    0.697349
# 2023-08-26    0.529534
# 2023-08-27    0.456265
# 2023-08-28    0.826003
# 2023-08-29    0.798961
# 2023-08-30    0.377494
# 2023-08-31    0.895047
# Freq: D, Name: C1, dtype: float64

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
del df1['B']
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  4.0
# e  NaN

# %%
dict = {'A' : pd.Series([1, 2, 3,11], index=['a', 'b', 'c','d']),
'B' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df12 = pd.DataFrame(dict)
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['c'], axis=0, inplace=True) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# d  11  4

# %%
col1 = np.linspace(10, 100, 30)
col2 = np.random.randint(10,100,30)
df10 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df10
# Out:
#             C1  C2
# 0    10.000000  41
# 1    13.103448  89
# 2    16.206897  83
# 3    19.310345  17
# 4    22.413793  69
# 5    25.517241  98
# 6    28.620690  58
# 7    31.724138  75
# 8    34.827586  45
# 9    37.931034  30
# 10   41.034483  19
# 11   44.137931  43
# 12   47.241379  60
# 13   50.344828  92
# 14   53.448276  88
# 15   56.551724  92
# 16   59.655172  61
# 17   62.758621  47
# 18   65.862069  27
# 19   68.965517  62
# 20   72.068966  68
# 21   75.172414  28
# 22   78.275862  86
# 23   81.379310  10
# 24   84.482759  97
# 25   87.586207  32
# 26   90.689655  71
# 27   93.793103  86
# 28   96.896552  81
# 29  100.000000  96

# %%
df10 = df10.drop([17,18,19], axis=0)
df10
# Out:
#             C1  C2
# 0    10.000000  41
# 1    13.103448  89
# 2    16.206897  83
# 3    19.310345  17
# 4    22.413793  69
# 5    25.517241  98
# 6    28.620690  58
# 7    31.724138  75
# 8    34.827586  45
# 9    37.931034  30
# 10   41.034483  19
# 11   44.137931  43
# 12   47.241379  60
# 13   50.344828  92
# 14   53.448276  88
# 15   56.551724  92
# 16   59.655172  61
# 20   72.068966  68
# 21   75.172414  28
# 22   78.275862  86
# 23   81.379310  10
# 24   84.482759  97
# 25   87.586207  32
# 26   90.689655  71
# 27   93.793103  86
# 28   96.896552  81
# 29  100.000000  96

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  41
# 1    13.103448  89
# 2    16.206897  83
# 3    19.310345  17
# 4    22.413793  69
# 5    25.517241  98
# 6    28.620690  58
# 7    31.724138  75
# 8    34.827586  45
# 9    37.931034  30
# 10   41.034483  19
# 11   44.137931  43
# 12   47.241379  60
# 13   50.344828  92
# 14   53.448276  88
# 15   56.551724  92
# 16   59.655172  61
# 20   72.068966  68
# 21   75.172414  28
# 22   78.275862  86
# 23   81.379310  10
# 24   84.482759  97
# 25   87.586207  32
# 26   90.689655  71
# 27   93.793103  86
# 28   96.896552  81
# 29  100.000000  96

# %%
df10.drop([16], axis=0, inplace=True)
df10
# Out:
#             C1  C2
# 0    10.000000  41
# 1    13.103448  89
# 2    16.206897  83
# 3    19.310345  17
# 4    22.413793  69
# 5    25.517241  98
# 6    28.620690  58
# 7    31.724138  75
# 8    34.827586  45
# 9    37.931034  30
# 10   41.034483  19
# 11   44.137931  43
# 12   47.241379  60
# 13   50.344828  92
# 14   53.448276  88
# 15   56.551724  92
# 20   72.068966  68
# 21   75.172414  28
# 22   78.275862  86
# 23   81.379310  10
# 24   84.482759  97
# 25   87.586207  32
# 26   90.689655  71
# 27   93.793103  86
# 28   96.896552  81
# 29  100.000000  96

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  41
# 1    13.103448  89
# 2    16.206897  83
# 3    19.310345  17
# 4    22.413793  69
# 5    25.517241  98
# 6    28.620690  58
# 7    31.724138  75
# 8    34.827586  45
# 9    37.931034  30
# 10   41.034483  19
# 11   44.137931  43
# 12   47.241379  60
# 13   50.344828  92
# 14   53.448276  88
# 15   56.551724  92
# 20   72.068966  68
# 21   75.172414  28
# 22   78.275862  86
# 23   81.379310  10
# 24   84.482759  97
# 25   87.586207  32
# 26   90.689655  71
# 27   93.793103  86
# 28   96.896552  81
# 29  100.000000  96

# %%
df10.drop(df10.index[5], inplace=True)

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  41
# 1    13.103448  89
# 2    16.206897  83
# 3    19.310345  17
# 4    22.413793  69
# 6    28.620690  58
# 7    31.724138  75
# 8    34.827586  45
# 9    37.931034  30
# 10   41.034483  19
# 11   44.137931  43
# 12   47.241379  60
# 13   50.344828  92
# 14   53.448276  88
# 15   56.551724  92
# 20   72.068966  68
# 21   75.172414  28
# 22   78.275862  86
# 23   81.379310  10
# 24   84.482759  97
# 25   87.586207  32
# 26   90.689655  71
# 27   93.793103  86
# 28   96.896552  81
# 29  100.000000  96

# %%
df10.iloc[10:15]
# Out:
#            C1  C2
# 11  44.137931  43
# 12  47.241379  60
# 13  50.344828  92
# 14  53.448276  88
# 15  56.551724  92

# %%
df10.loc[10:15, 'C1']
# Out:
# 10    41.034483
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df10.iloc[10:15, 0]
# Out:
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df10.loc[10:,'C1':]
# Out:
#             C1  C2
# 10   41.034483  19
# 11   44.137931  43
# 12   47.241379  60
# 13   50.344828  92
# 14   53.448276  88
# 15   56.551724  92
# 20   72.068966  68
# 21   75.172414  28
# 22   78.275862  86
# 23   81.379310  10
# 24   84.482759  97
# 25   87.586207  32
# 26   90.689655  71
# 27   93.793103  86
# 28   96.896552  81
# 29  100.000000  96

# %%
df10.iloc[10:, 0:]
# Out:
#             C1  C2
# 11   44.137931  43
# 12   47.241379  60
# 13   50.344828  92
# 14   53.448276  88
# 15   56.551724  92
# 20   72.068966  68
# 21   75.172414  28
# 22   78.275862  86
# 23   81.379310  10
# 24   84.482759  97
# 25   87.586207  32
# 26   90.689655  71
# 27   93.793103  86
# 28   96.896552  81
# 29  100.000000  96

# %% [markdown]
# #**Tuesday Sept 05, 2023**

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.loc[:,:]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.loc['2023-08-28':,:]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.loc[:'28-08-2023',:]
# Out:
# <ipython-input-54-6037633cf9bf>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc[:'28-08-2023',:]
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
#
#                   C7
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705

# %%
df.loc[:,'C4':]
# Out:
#                   C4        C5        C6        C7
# 2023-08-25  0.059928  0.045637  0.470307  0.965918
# 2023-08-26  0.344236  0.485332  0.204292  0.971256
# 2023-08-27  0.717988  0.030115  0.050010  0.823117
# 2023-08-28  0.042578  0.814370  0.807989  0.869705
# 2023-08-29  0.576229  0.247239  0.530211  0.048377
# 2023-08-30  0.640909  0.064288  0.432932  0.031390
# 2023-08-31  0.737546  0.611173  0.391509  0.252844

# %%
df.loc[:,:'C4']
# Out:
#                   C1        C2        C3        C4
# 2023-08-25  0.697349  0.841127  0.669636  0.059928
# 2023-08-26  0.529534  0.221786  0.209045  0.344236
# 2023-08-27  0.456265  0.210619  0.217024  0.717988
# 2023-08-28  0.826003  0.246994  0.496508  0.042578
# 2023-08-29  0.798961  0.832146  0.608760  0.576229
# 2023-08-30  0.377494  0.197784  0.919021  0.640909
# 2023-08-31  0.895047  0.339036  0.761758  0.737546

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.loc['25-08-2023':'25-08-2023','C1':'C1']
# Out:
# <ipython-input-58-67d2a7753ad7>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023':'25-08-2023','C1':'C1']
#                   C1
# 2023-08-25  0.697349

# %%
df.loc['26-08-2023':'26-08-2023','C2':'C2']
# Out:
# <ipython-input-59-1fd126cf03ec>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023':'26-08-2023','C2':'C2']
#                   C2
# 2023-08-26  0.221786

# %%
df.loc['27-08-2023':'27-08-2023','C3':'C3']
# Out:
# <ipython-input-60-0598eea2a8b0>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023':'27-08-2023','C3':'C3']
#                   C3
# 2023-08-27  0.217024

# %%
df.loc['28-08-2023':'28-08-2023','C4':'C4']
# Out:
# <ipython-input-61-97a2393ef63f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023':'28-08-2023','C4':'C4']
#                   C4
# 2023-08-28  0.042578

# %%
df.loc['29-08-2023':'29-08-2023','C5':'C5']
# Out:
# <ipython-input-62-d737984eb42f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023':'29-08-2023','C5':'C5']
#                   C5
# 2023-08-29  0.247239

# %%
df.loc['30-08-2023':'30-08-2023','C6':'C6']
# Out:
# <ipython-input-63-999a0150c3ba>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023':'30-08-2023','C6':'C6']
#                   C6
# 2023-08-30  0.432932

# %%
df.loc['31-08-2023':'31-08-2023','C7':'C7']
# Out:
# <ipython-input-64-acca78fa93ce>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023':'31-08-2023','C7':'C7']
#                   C7
# 2023-08-31  0.252844

# %%
#Reverse diagonal

df.loc['31-08-2023':'31-08-2023','C1':'C1']
# Out:
# <ipython-input-65-62dc75061337>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023':'31-08-2023','C1':'C1']
#                   C1
# 2023-08-31  0.895047

# %%
df.loc['30-08-2023':'30-08-2023','C2':'C2']
# Out:
# <ipython-input-66-c519add2ac00>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023':'30-08-2023','C2':'C2']
#                   C2
# 2023-08-30  0.197784

# %%
df.loc['29-08-2023':'29-08-2023','C3':'C3']
# Out:
# <ipython-input-67-5dbebb6eca1f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023':'29-08-2023','C3':'C3']
#                  C3
# 2023-08-29  0.60876

# %%
df.loc['28-08-2023':'28-08-2023','C4':'C4']
# Out:
# <ipython-input-68-97a2393ef63f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023':'28-08-2023','C4':'C4']
#                   C4
# 2023-08-28  0.042578

# %%
df.loc['27-08-2023':'27-08-2023','C5':'C5']
# Out:
# <ipython-input-69-bca961938129>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023':'27-08-2023','C5':'C5']
#                   C5
# 2023-08-27  0.030115

# %%
df.loc['26-08-2023':'26-08-2023','C6':'C6']
# Out:
# <ipython-input-70-e8718737b6fc>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023':'26-08-2023','C6':'C6']
#                   C6
# 2023-08-26  0.204292

# %%
df.loc['25-08-2023':'25-08-2023','C7':'C7']
# Out:
# <ipython-input-71-f8296650380d>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023':'25-08-2023','C7':'C7']
#                   C7
# 2023-08-25  0.965918

# %%
df.loc['2023-08-28':,:]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.loc[:'28-08-2023',:]
# Out:
# <ipython-input-73-6037633cf9bf>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc[:'28-08-2023',:]
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
#
#                   C7
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705

# %%
df.loc[:,'C4':]
# Out:
#                   C4        C5        C6        C7
# 2023-08-25  0.059928  0.045637  0.470307  0.965918
# 2023-08-26  0.344236  0.485332  0.204292  0.971256
# 2023-08-27  0.717988  0.030115  0.050010  0.823117
# 2023-08-28  0.042578  0.814370  0.807989  0.869705
# 2023-08-29  0.576229  0.247239  0.530211  0.048377
# 2023-08-30  0.640909  0.064288  0.432932  0.031390
# 2023-08-31  0.737546  0.611173  0.391509  0.252844

# %%
df.loc[:,:'C4']
# Out:
#                   C1        C2        C3        C4
# 2023-08-25  0.697349  0.841127  0.669636  0.059928
# 2023-08-26  0.529534  0.221786  0.209045  0.344236
# 2023-08-27  0.456265  0.210619  0.217024  0.717988
# 2023-08-28  0.826003  0.246994  0.496508  0.042578
# 2023-08-29  0.798961  0.832146  0.608760  0.576229
# 2023-08-30  0.377494  0.197784  0.919021  0.640909
# 2023-08-31  0.895047  0.339036  0.761758  0.737546

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.iloc[:,:]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.iloc[6:,:1]
# Out:
#                   C1
# 2023-08-31  0.895047

# %%
df.iloc[5:6,1:2]
# Out:
#                   C2
# 2023-08-30  0.197784

# %%
df.iloc[4:5,2:3]
# Out:
#                  C3
# 2023-08-29  0.60876

# %%
df.iloc[3:4,3:4]
# Out:
#                   C4
# 2023-08-28  0.042578

# %%
df.iloc[2:3,4:5]
# Out:
#                   C5
# 2023-08-27  0.030115

# %%
df.iloc[1:2,5:6]
# Out:
#                   C6
# 2023-08-26  0.204292

# %%
df.iloc[:1,6:]
# Out:
#                   C7
# 2023-08-25  0.965918

# %%
df.iloc[:,:2]
# Out:
#                   C1        C2
# 2023-08-25  0.697349  0.841127
# 2023-08-26  0.529534  0.221786
# 2023-08-27  0.456265  0.210619
# 2023-08-28  0.826003  0.246994
# 2023-08-29  0.798961  0.832146
# 2023-08-30  0.377494  0.197784
# 2023-08-31  0.895047  0.339036

# %%
df.iloc[:,4:]
# Out:
#                   C5        C6        C7
# 2023-08-25  0.045637  0.470307  0.965918
# 2023-08-26  0.485332  0.204292  0.971256
# 2023-08-27  0.030115  0.050010  0.823117
# 2023-08-28  0.814370  0.807989  0.869705
# 2023-08-29  0.247239  0.530211  0.048377
# 2023-08-30  0.064288  0.432932  0.031390
# 2023-08-31  0.611173  0.391509  0.252844

# %%
df.iloc[3:,:]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
# 2023-08-29  0.798961  0.832146  0.608760  0.576229  0.247239  0.530211
# 2023-08-30  0.377494  0.197784  0.919021  0.640909  0.064288  0.432932
# 2023-08-31  0.895047  0.339036  0.761758  0.737546  0.611173  0.391509
#
#                   C7
# 2023-08-28  0.869705
# 2023-08-29  0.048377
# 2023-08-30  0.031390
# 2023-08-31  0.252844

# %%
df.iloc[:4,:]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.697349  0.841127  0.669636  0.059928  0.045637  0.470307
# 2023-08-26  0.529534  0.221786  0.209045  0.344236  0.485332  0.204292
# 2023-08-27  0.456265  0.210619  0.217024  0.717988  0.030115  0.050010
# 2023-08-28  0.826003  0.246994  0.496508  0.042578  0.814370  0.807989
#
#                   C7
# 2023-08-25  0.965918
# 2023-08-26  0.971256
# 2023-08-27  0.823117
# 2023-08-28  0.869705

# %%
df.iloc[:,3:]
# Out:
#                   C4        C5        C6        C7
# 2023-08-25  0.059928  0.045637  0.470307  0.965918
# 2023-08-26  0.344236  0.485332  0.204292  0.971256
# 2023-08-27  0.717988  0.030115  0.050010  0.823117
# 2023-08-28  0.042578  0.814370  0.807989  0.869705
# 2023-08-29  0.576229  0.247239  0.530211  0.048377
# 2023-08-30  0.640909  0.064288  0.432932  0.031390
# 2023-08-31  0.737546  0.611173  0.391509  0.252844

# %%
df.iloc[:,:4]
# Out:
#                   C1        C2        C3        C4
# 2023-08-25  0.697349  0.841127  0.669636  0.059928
# 2023-08-26  0.529534  0.221786  0.209045  0.344236
# 2023-08-27  0.456265  0.210619  0.217024  0.717988
# 2023-08-28  0.826003  0.246994  0.496508  0.042578
# 2023-08-29  0.798961  0.832146  0.608760  0.576229
# 2023-08-30  0.377494  0.197784  0.919021  0.640909
# 2023-08-31  0.895047  0.339036  0.761758  0.737546

# %%
path = '/content/Churn_Modelling.csv'
df_churn_mod = pd.read_csv(path)
df_churn_mod
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod.iloc[10:100,5:10]
# Out:
#     Gender  Age  Tenure    Balance  NumOfProducts
# 10    Male   31       6  102016.72              2
# 11    Male   24       3       0.00              2
# 12  Female   34      10       0.00              2
# 13  Female   25       5       0.00              2
# 14  Female   35       7       0.00              2
# ..     ...  ...     ...        ...            ...
# 95    Male   35      10  176273.95              1
# 96    Male   41       9  102827.44              1
# 97    Male   29       8   97086.40              2
# 98    Male   22       8       0.00              2
# 99    Male   34       9       0.00              2
#
# [90 rows x 5 columns]

# %%
df_churn_mod.iloc[10:20,10:14]
# Out:
#     HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 10          0               0         80181.12       0
# 11          1               0         76390.01       0
# 12          1               0         26260.98       0
# 13          0               0        190857.79       0
# 14          1               1         65951.65       0
# 15          0               1         64327.26       0
# 16          1               0          5097.67       1
# 17          1               1         14406.41       0
# 18          0               0        158684.81       0
# 19          1               1         54724.03       0

# %%
df_churn_mod.info()
#int64--->integer window 64
#float---->float window 64
#object----> string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df_churn_mod.describe() #statistics (mean, median, mode) #describe w/ () is function
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df_churn_mod.describe(include='all') #includes nan values
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
df_churn_mod.describe #describe w/o () is attributes
# Out:
# <bound method NDFrame.describe of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
df_churn_mod.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df_churn_mod.size #size of table
# Out:
# 140000

# %%
df_churn_mod.ndim #gives dimension of data
# Out:
# 2

# %%
df_churn_mod.columns #column titles
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_churn_mod.count #how many rows and columns combined
# Out:
# <bound method DataFrame.count of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
df_churn_mod.shape #shape of data
# Out:
# (10000, 14)

# %%
df_churn_mod.isnull() #gives statistics as how many values are null
#here, no value is null as it is giving false result
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
df_churn_mod.isnull().sum()
#here, all is zero(0) which means there is no null value
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df_churn_mod.min()
# Out:
# RowNumber                 1
# CustomerId         15565701
# Surname               Abazu
# CreditScore             350
# Geography            France
# Gender               Female
# Age                      18
# Tenure                    0
# Balance                 0.0
# NumOfProducts             1
# HasCrCard                 0
# IsActiveMember            0
# EstimatedSalary       11.58
# Exited                    0
# dtype: object

# %%
df_churn_mod.max()
# Out:
# RowNumber              10000
# CustomerId          15815690
# Surname               Zuyeva
# CreditScore              850
# Geography              Spain
# Gender                  Male
# Age                       92
# Tenure                    10
# Balance            250898.09
# NumOfProducts              4
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    199992.48
# Exited                     1
# dtype: object

# %%
df_churn_mod.std()
# Out:
# <ipython-input-109-4aed2d4f720c>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_churn_mod.std()
# RowNumber           2886.895680
# CustomerId         71936.186123
# CreditScore           96.653299
# Age                   10.487806
# Tenure                 2.892174
# Balance            62397.405202
# NumOfProducts          0.581654
# HasCrCard              0.455840
# IsActiveMember         0.499797
# EstimatedSalary    57510.492818
# Exited                 0.402769
# dtype: float64

# %%
df_churn_mod.sum()
# Out:
# RowNumber                                                   50005000
# CustomerId                                              156909405694
# Surname            HargraveHillOnioBoniMitchellChuBartlettObinnaH...
# CreditScore                                                  6505288
# Geography          FranceSpainFranceFranceSpainSpainFranceGermany...
# Gender             FemaleFemaleFemaleFemaleFemaleMaleMaleFemaleMa...
# Age                                                           389218
# Tenure                                                         50128
# Balance                                                 764858892.88
# NumOfProducts                                                  15302
# HasCrCard                                                       7055
# IsActiveMember                                                  5151
# EstimatedSalary                                        1000902398.81
# Exited                                                          2037
# ...

# %%
df_churn_mod.columns #taking column by column and slicing values
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_churn_mod.RowNumber #if there is no space in between the columm name e.g: rownumber
# Out:
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#         ...
# 9995     9996
# 9996     9997
# 9997     9998
# 9998     9999
# 9999    10000
# Name: RowNumber, Length: 10000, dtype: int64

# %%
df_churn_mod['RowNumber'] #other way to slice column if the column name has space in name or not
# Out:
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#         ...
# 9995     9996
# 9996     9997
# 9997     9998
# 9998     9999
# 9999    10000
# Name: RowNumber, Length: 10000, dtype: int64

# %%
df_churn_mod.CreditScore, df_churn_mod.Geography
# Out:
# (0       619
#  1       608
#  2       502
#  3       699
#  4       850
#         ...
#  9995    771
#  9996    516
#  9997    709
#  9998    772
#  9999    792
#  Name: CreditScore, Length: 10000, dtype: int64,
#  0        France
#  1         Spain
#  2        France
#  3        France
#  4         Spain
#           ...
#  9995     France
#  9996     France
#  9997     France
#  9998    Germany
#  9999     France
#  Name: Geography, Length: 10000, dtype: object)

# %%
df_churn_mod[['CreditScore', 'Geography']] #there are 2 brackets as it is 2 dimensional
# Out:
#       CreditScore Geography
# 0             619    France
# 1             608     Spain
# 2             502    France
# 3             699    France
# 4             850     Spain
# ...           ...       ...
# 9995          771    France
# 9996          516    France
# 9997          709    France
# 9998          772   Germany
# 9999          792    France
#
# [10000 rows x 2 columns]

# %%
df_churn_mod[['Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard']]
# Out:
#       Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard
# 0     Female   42       2       0.00              1          1
# 1     Female   41       1   83807.86              1          0
# 2     Female   42       8  159660.80              3          1
# 3     Female   39       1       0.00              2          0
# 4     Female   43       2  125510.82              1          1
# ...      ...  ...     ...        ...            ...        ...
# 9995    Male   39       5       0.00              2          1
# 9996    Male   35      10   57369.61              1          1
# 9997  Female   36       7       0.00              1          0
# 9998    Male   42       3   75075.31              2          1
# 9999  Female   28       4  130142.79              1          1
#
# [10000 rows x 6 columns]

# %% [markdown]
# #**Data selection based on Condition**

# %%
df_churn_mod[df_churn_mod.Gender == 'Male'] # == is comparison operator
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
# ...

# %%
df_churn_mod[(df_churn_mod.Gender == 'Male') & (df_churn_mod.Age >= 45)]
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  \
# 6             7    15592531  Bartlett          822    France   Male   50
# 15           16    15643966   Goforth          616   Germany   Male   45
# 16           17    15737452     Romeo          653   Germany   Male   58
# 18           19    15661507   Muldrow          587     Spain   Male   45
# 23           24    15725737    Mosman          669    France   Male   46
# ...         ...         ...       ...          ...       ...    ...  ...
# 9953       9954    15655952     Burke          550    France   Male   47
# 9954       9955    15739850  Trentino          645    France   Male   45
# 9967       9968    15603794  Pugliesi          623    France   Male   48
# 9975       9976    15666295     Smith          610   Germany   Male   50
# 9986       9987    15581736  Bartlett          673   Germany   Male   47
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod[(df_churn_mod.Gender == 'Male') & (df_churn_mod.Age >= 45) & (df_churn_mod.Balance > 100000)]
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography Gender  Age  \
# 15           16    15643966     Goforth          616   Germany   Male   45
# 16           17    15737452       Romeo          653   Germany   Male   58
# 56           57    15630053        Tsao          656    France   Male   45
# 70           71    15703793  Konovalova          738   Germany   Male   58
# 91           92    15731511     Ritchie          808    France   Male   45
# ...         ...         ...         ...          ...       ...    ...  ...
# 9917       9918    15755731       Davis          635   Germany   Male   53
# 9954       9955    15739850    Trentino          645    France   Male   45
# 9967       9968    15603794    Pugliesi          623    France   Male   48
# 9975       9976    15666295       Smith          610   Germany   Male   50
# 9986       9987    15581736    Bartlett          673   Germany   Male   47
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod[(df_churn_mod.Surname == 'Smith' ) & (df_churn_mod.Age >= 45) & (df_churn_mod.Balance > 100000)]
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography  Gender  Age  \
# 234         235    15704769   Smith          585    France  Female   67
# 2541       2542    15679770   Smith          611    France  Female   61
# 7213       7214    15623210   Smith          484   Germany  Female   55
# 7270       7271    15706268   Smith          697   Germany    Male   51
# 7338       7339    15796111   Smith          708   Germany  Female   54
# 9056       9057    15793311   Smith          765   Germany  Female   46
# 9920       9921    15673020   Smith          678    France  Female   49
# 9975       9976    15666295   Smith          610   Germany    Male   50
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 234        5  113978.97              2          0               1
# 2541       3  131583.59              4          0               1
# 7213       8  149349.58              3          0               0
# ...

# %%
df_churn_mod.Surname.unique()
# Out:
# array(['Hargrave', 'Hill', 'Onio', ..., 'Kashiwagi', 'Aldridge',
#        'Burbidge'], dtype=object)

# %%
df_churn_mod[df_churn_mod.Geography.isin(['France','Germany'])]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# #**Sept 06, 2023**

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df_chipotle = pd.read_csv(url, sep='\t')
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_chipotle [df_chipotle.item_name != 'Steak Burrito']
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4615      1832         1                     Chicken Soft Tacos
# 4616      1832         1                    Chips and Guacamole
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_chipotle[(df_chipotle.item_name=="Chicken Bowl") & (df_chipotle.quantity==2)]
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 154         70         2  Chicken Bowl
# 282        124         2  Chicken Bowl
# 415        181         2  Chicken Bowl
# 654        271         2  Chicken Bowl
# 976        401         2  Chicken Bowl
# 1017       418         2  Chicken Bowl
# 1106       457         2  Chicken Bowl
# 1429       578         2  Chicken Bowl
# 1588       643         2  Chicken Bowl
# 1832       741         2  Chicken Bowl
# 2075       837         2  Chicken Bowl
# 2106       848         2  Chicken Bowl
# 2339       932         2  Chicken Bowl
# 2510       997         2  Chicken Bowl
# 2525      1004         2  Chicken Bowl
# 2580      1023         2  Chicken Bowl
# 2771      1100         2  Chicken Bowl
# 2942      1170         2  Chicken Bowl
# 3080      1227         2  Chicken Bowl
# 3133      1249         2  Chicken Bowl
# 3151      1257         2  Chicken Bowl
# 3423      1374         2  Chicken Bowl
# ...

# %%
df_chipotle[df_chipotle.item_name.isin(['chicken Bowl', 'Chicken Burrito'])]
# Out:
#       order_id  quantity        item_name  \
# 16           8         1  Chicken Burrito
# 17           9         1  Chicken Burrito
# 23          12         1  Chicken Burrito
# 29          15         1  Chicken Burrito
# 45          21         1  Chicken Burrito
# ...        ...       ...              ...
# 4556      1811         1  Chicken Burrito
# 4558      1812         1  Chicken Burrito
# 4559      1812         1  Chicken Burrito
# 4566      1816         1  Chicken Burrito
# 4569      1817         1  Chicken Burrito
#
#                                      choice_description item_price
# 16    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 17    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...    $10.98
# 29    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 45    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $10.98
# ...

# %%
df_chipotle[df_chipotle.item_name == 'Chips and Fresh Tomato Salsa']
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 0        $2.39
# 25       $2.39
# 55       $2.39
# ...

# %%
df_chipotle.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
for value in df_chipotle.item_price:
  print(value[1:-1])

prices = [float(value[1:-1]) for value in df_chipotle.item_price]
df_chipotle.item_price = prices
# Out:
# 2.39
# 3.39
# 3.39
# 2.39
# 16.98
# 10.98
# 1.69
# 11.75
# 9.25
# 9.25
# 4.45
# 8.75
# 8.75
# 11.25
# 4.45
# 2.39
# 8.49
# 8.49
# 2.18
# 8.75
# 4.45
# 8.99
# 3.39
# 10.98
# 3.39
# 2.39
# 8.49
# 8.99
# 1.09
# 8.49
# 2.39
# 8.99
# 1.69
# 8.99
# 1.09
# 8.75
# 8.75
# 4.45
# 2.95
# 11.75
# 2.15
# 4.45
# 11.25
# 11.75
# 8.75
# 10.98
# 8.99
# 3.39
# 8.99
# 3.99
# 8.99
# 2.18
# 10.98
# 1.09
# 8.99
# 2.39
# 9.25
# 11.25
# 11.75
# 2.15
# 4.45
# 9.25
# 11.25
# 8.75
# 8.99
# 8.99
# 3.39
# 8.99
# 10.98
# 8.99
# 1.69
# 8.99
# 3.99
# 8.75
# 4.45
# 8.75
# 8.75
# 2.15
# 8.75
# 11.25
# 2.15
# 9.25
# 8.75
# 8.75
# 9.25
# 8.49
# 8.99
# 1.09
# 9.25
# 2.95
# 11.75
# 11.75
# 9.25
# 11.75
# 4.45
# 9.25
# 4.45
# 11.75
# 8.75
# 8.75
# 4.45
# 8.99
# 8.99
# 3.99
# 8.49
# 3.39
# 8.99
# 1.09
# 9.25
# 4.45
# 8.75
# 2.95
# 4.45
# 2.39
# 8.49
# 8.99
# 8.49
# 1.09
# 8.99
# 3.99
# 8.75
# 9.25
# 4.45
# 11.25
# 4.45
# 8.99
# 1.09
# 9.25
# 2.95
# 4.45
# 11.75
# 4.45
# 8.49
# 2.39
# 10.98
# 22.50
# 11.75
# 4.45
# 11.25
# ...

# %%
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df_chipotle[df_chipotle.item_price > 10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
df_chipotle.filter(like='item', axis=1)
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
df_chipotle.filter(regex='e$', axis=1)
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
df_chipotle.filter(items=['choice_description', 'quantity'])
# Out:
#                                      choice_description  quantity
# 0                                                   NaN         1
# 1                                          [Clementine]         1
# 2                                               [Apple]         1
# 3                                                   NaN         1
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...         2
# ...                                                 ...       ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...         1
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...         1
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         1
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...         1
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         1
#
# [4622 rows x 2 columns]

# %%
df_chipotle[df_chipotle.choice_description.isin(['[Clementine]'])]
# Out:
#       order_id  quantity item_name choice_description  item_price
# 1            1         1      Izze       [Clementine]        3.39
# 579        237         1      Izze       [Clementine]        3.39
# 1059       436         1      Izze       [Clementine]        3.39
# 1213       495         1      Izze       [Clementine]        3.39
# 1680       680         1      Izze       [Clementine]        3.39
# 2088       842         1      Izze       [Clementine]        3.39
# 2619      1040         1      Izze       [Clementine]        3.39
# 2634      1046         1      Izze       [Clementine]        3.39

# %%
df_chipotle[df_chipotle.choice_description.str.contains('Clementine')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-4b4c783ad4c1> in <cell line: 1>()
# ----> 1 df_chipotle[df_chipotle.choice_description.str.contains('Clementine')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3795
#    3796         # Do we have a (boolean) 1d indexer?
# -> 3797         if com.is_bool_indexer(key):
#    3798             return self._getitem_bool_array(key)
#    3799
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     133                     # Don't raise on e.g. ["A", "B", np.nan], see
#     134                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135                     raise ValueError(na_msg)
#     136                 return False
#     137             return True
#
# ...

# %%
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df_users = pd.read_csv(url, sep='|')
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df_users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
df_users.occupation.unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
df_users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
df_users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
df_users.groupby('occupation').sum()
# Out:
# <ipython-input-143-ae37452f49f5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby('occupation').sum()
#                user_id   age
# occupation
# administrator    34045  3061
# artist           12653   879
# doctor            3736   305
# educator         44356  3991
# engineer         30574  2438
# entertainment     7164   526
# executive        13514  1239
# healthcare        8023   665
# homemaker         3101   228
# lawyer            4309   441
# librarian        24816  2040
# marketing        11383   978
# none              3318   239
# other            56987  3625
# programmer       28745  2186
# retired           7220   883
# salesman          5939   428
# scientist        14419  1102
# student          95051  4328
# technician       13436   895
# ...

# %%
df_users.groupby('occupation').count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       79   79      79        79
# artist              28   28      28        28
# doctor               7    7       7         7
# educator            95   95      95        95
# engineer            67   67      67        67
# entertainment       18   18      18        18
# executive           32   32      32        32
# healthcare          16   16      16        16
# homemaker            7    7       7         7
# lawyer              12   12      12        12
# librarian           51   51      51        51
# marketing           26   26      26        26
# none                 9    9       9         9
# other              105  105     105       105
# programmer          66   66      66        66
# retired             14   14      14        14
# salesman            12   12      12        12
# scientist           31   31      31        31
# student            196  196     196       196
# ...

# %%
df_users.groupby('occupation').age.count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: age, dtype: int64

# %%
df_users.groupby('zip_code').first()
# Out:
#           user_id  age gender     occupation
# zip_code
# 00000         186   39      F      executive
# 01002           9   29      M        student
# 01040          39   41      M  entertainment
# 01080         231   48      M      librarian
# 01331          55   37      M     programmer
# ...           ...  ...    ...            ...
# V0R2M         333   47      M          other
# V1G4L         857   35      F  administrator
# V3N4P         145   31      M  entertainment
# V5A2B         490   29      F         artist
# Y1A6B         458   47      M     technician
#
# [795 rows x 4 columns]

# %%
df_users.groupby('zip_code').last()
# Out:
#           user_id  age gender     occupation
# zip_code
# 00000         767   70      M       engineer
# 01002           9   29      M        student
# 01040          39   41      M  entertainment
# 01080         231   48      M      librarian
# 01331          55   37      M     programmer
# ...           ...  ...    ...            ...
# V0R2M         333   47      M          other
# V1G4L         857   35      F  administrator
# V3N4P         145   31      M  entertainment
# V5A2B         490   29      F         artist
# Y1A6B         458   47      M     technician
#
# [795 rows x 4 columns]

# %%
df_users.groupby('gender').size()
# Out:
# gender
# F    273
# M    670
# dtype: int64

# %%
df_users.groupby('gender').last()
# Out:
#         user_id  age occupation zip_code
# gender
# F           942   48  librarian    78209
# M           943   22    student    77841

# %%
df_users.groupby('zip_code').nth(-1)
# Out:
#           user_id  age gender     occupation
# zip_code
# 00000         767   70      M       engineer
# 01002           9   29      M        student
# 01040          39   41      M  entertainment
# 01080         231   48      M      librarian
# 01331          55   37      M     programmer
# ...           ...  ...    ...            ...
# V0R2M         333   47      M          other
# V1G4L         857   35      F  administrator
# V3N4P         145   31      M  entertainment
# V5A2B         490   29      F         artist
# Y1A6B         458   47      M     technician
#
# [795 rows x 4 columns]

# %%
df_users.query("occupation == 'homemaker'").groupby(['occupation', 'gender']).count()
# Out:
#                    user_id  age  zip_code
# occupation gender
# homemaker  F             6    6         6
#            M             1    1         1

# %%
df_homemaker = df_users[df_users['occupation'] == 'homemaker'].groupby('gender').count()
df_homemaker
# Out:
#         user_id  age  occupation  zip_code
# gender
# F             6    6           6         6
# M             1    1           1         1

# %% [markdown]
# #**Sept 07, 2023**

# %%
df_users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
df_users.age
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
df_users.groupby('age').occupation.count()
# Out:
# age
# 7     1
# 10    1
# 11    1
# 13    5
# 14    3
#      ..
# 66    1
# 68    2
# 69    2
# 70    3
# 73    1
# Name: occupation, Length: 61, dtype: int64

# %%
df_users.groupby('gender').occupation.count()
# Out:
# gender
# F    273
# M    670
# Name: occupation, dtype: int64

# %%
df_users.groupby('zip_code').occupation.count()
# Out:
# zip_code
# 00000    2
# 01002    1
# 01040    1
# 01080    1
# 01331    1
#         ..
# V0R2M    1
# V1G4L    1
# V3N4P    1
# V5A2B    1
# Y1A6B    1
# Name: occupation, Length: 795, dtype: int64

# %%
import numpy as np
import pandas as pd

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'],
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %%
regiment = pd.DataFrame(raw_data, columns = raw_data.keys())

# %%
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %%
regiment.groupby('regiment').company.count()
# Out:
# regiment
# Dragoons      4
# Nighthawks    4
# Scouts        4
# Name: company, dtype: int64

# %%
regiment[regiment['regiment']=='Scouts'].groupby('regiment').count()
# Out:
#           company  name  preTestScore  postTestScore
# regiment
# Scouts          4     4             4              4

# %%
regiment[regiment['postTestScore'] > 50].groupby('name').count()
# Out:
#           regiment  company  preTestScore  postTestScore
# name
# Ali              2        2             2              2
# Cooze            1        1             1              1
# Jacobson         1        1             1              1
# Milner           1        1             1              1
# Piger            1        1             1              1
# Riani            1        1             1              1
# Ryaner           1        1             1              1
# Sloan            1        1             1              1
# Sone             1        1             1              1

# %%
regiment.groupby('company').describe()
# Out:
#         preTestScore                                                      \
#                count       mean        std  min   25%   50%    75%   max
# company
# 1st              6.0   6.666667   8.524475  2.0  3.00   3.5   4.00  24.0
# 2nd              6.0  15.500000  14.652645  2.0  2.25  13.5  29.25  31.0
#
#         postTestScore
#                 count       mean        std   min    25%   50%   75%   max
# company
# 1st               6.0  57.666667  27.485754  25.0  34.25  66.0  70.0  94.0
# 2nd               6.0  67.000000  14.057027  57.0  58.25  62.0  68.0  94.0

# %%
regiment.groupby('company').preTestScore.mean()
# Out:
# company
# 1st     6.666667
# 2nd    15.500000
# Name: preTestScore, dtype: float64

# %%
regiment.groupby(['regiment', 'company']).preTestScore.mean()
# Out:
# regiment    company
# Dragoons    1st         3.5
#             2nd        27.5
# Nighthawks  1st        14.0
#             2nd        16.5
# Scouts      1st         2.5
#             2nd         2.5
# Name: preTestScore, dtype: float64

# %%
regiment.groupby(['regiment', 'company']).preTestScore.mean().unstack()
# Out:
# company      1st   2nd
# regiment
# Dragoons     3.5  27.5
# Nighthawks  14.0  16.5
# Scouts       2.5   2.5

# %%
regiment.groupby(['regiment', 'company']).mean()
# Out:
# <ipython-input-172-5808efbeaedb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   regiment.groupby(['regiment', 'company']).mean()
#                     preTestScore  postTestScore
# regiment   company
# Dragoons   1st               3.5           47.5
#            2nd              27.5           75.5
# Nighthawks 1st              14.0           59.5
#            2nd              16.5           59.5
# Scouts     1st               2.5           66.0
#            2nd               2.5           66.0

# %%
regiment.groupby(['company', 'regiment']).size()
# Out:
# company  regiment
# 1st      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# 2nd      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# dtype: int64

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %%
df_uscrime = pd.read_csv(url)
df_uscrime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
df_uscrime.info
# Out:
# <bound method DataFrame.info of     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# ...

# %%
df_uscrime.describe()
# Out:
#              Year    Population         Total       Violent      Property  \
# count    55.00000  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   1987.00000  2.461556e+08  1.060315e+07  1.188806e+06  9.412499e+06
# std      16.02082  4.166216e+07  3.175931e+06  4.597107e+05  2.738512e+06
# min    1960.00000  1.793232e+08  3.384200e+06  2.884600e+05  3.095700e+06
# 25%    1973.50000  2.106215e+08  9.096958e+06  9.253150e+05  8.060014e+06
# 50%    1987.00000  2.422829e+08  1.140151e+07  1.322390e+06  1.018259e+07
# 75%    2000.50000  2.833697e+08  1.308449e+07  1.432762e+06  1.160509e+07
# max    2014.00000  3.188571e+08  1.487290e+07  1.932270e+06  1.296110e+07
#
#              Murder  Forcible_Rape        Robbery  Aggravated_assault  \
# count     55.000000      55.000000      55.000000        5.500000e+01
# mean   17317.236364   72714.800000  416449.890909        6.811818e+05
# std     4267.442664   28278.006893  150506.403782        2.960255e+05
# ...

# %%
df_uscrime.shape
# Out:
# (55, 12)

# %%
df_uscrime.size
# Out:
# 660

# %%
df_uscrime.loc[0:9,['Year','Robbery']]
# Out:
#    Year  Robbery
# 0  1960   107840
# 1  1961   106670
# 2  1962   110860
# 3  1963   116470
# 4  1964   130390
# 5  1965   138690
# 6  1966   157990
# 7  1967   202910
# 8  1968   262840
# 9  1969   298850

# %%
df_uscrime.iloc[5:6,:6]
# Out:
#    Year  Population    Total  Violent  Property  Murder
# 5  1965   193526000  4739400   387390   4352000    9960

# %%
df_uscrime.loc[40:40,:]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 40  2000   281421906  11608072  1425486  10182586   15586          90178
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 40   408016              911706   2050992        6971590        1160002

# %%
df_uscrime.count()
# Out:
# Year                  55
# Population            55
# Total                 55
# Violent               55
# Property              55
# Murder                55
# Forcible_Rape         55
# Robbery               55
# Aggravated_assault    55
# Burglary              55
# Larceny_Theft         55
# Vehicle_Theft         55
# dtype: int64

# %%
df_uscrime['Robbery'].agg(['min','max'])
# Out:
# min    106670
# max    687730
# Name: Robbery, dtype: int64

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

# %%
data_new = pd.concat([data1, data2])
data_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new_row = pd.concat([data1, data2], axis=0)
data_new_row
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new_col = pd.concat([data1, data2], axis=1)
data_new_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
pd.merge(data_new, data3, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15
