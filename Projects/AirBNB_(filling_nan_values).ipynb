# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

path = '/content/AB_NYC_2019.csv'
df=pd.read_csv(path)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2             NaN                NaN                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# top              Manhattan  Williamsburg           NaN           NaN
# freq                 21661          3920           NaN           NaN
# mean                   NaN           NaN     40.728949    -73.952170
# std                    NaN           NaN      0.054530      0.046157
# min                    NaN           NaN     40.499790    -74.244420
# 25%                    NaN           NaN     40.690100    -73.983070
# 50%                    NaN           NaN     40.723070    -73.955680
# 75%                    NaN           NaN     40.763115    -73.936275
# max                    NaN           NaN     40.913060    -73.712990
#
#               room_type         price  minimum_nights  number_of_reviews  \
# count             48895  48895.000000    48895.000000       48895.000000
# unique                3           NaN             NaN                NaN
# top     Entire home/apt           NaN             NaN                NaN
# freq              25409           NaN             NaN                NaN
# mean                NaN    152.720687        7.029962          23.274466
# std                 NaN    240.154170       20.510550          44.550582
# min                 NaN      0.000000        1.000000           0.000000
# 25%                 NaN     69.000000        1.000000           1.000000
# 50%                 NaN    106.000000        3.000000           5.000000
# 75%                 NaN    175.000000        5.000000          24.000000
# max                 NaN  10000.000000     1250.000000         629.000000
#
#        last_review  reviews_per_month  calculated_host_listings_count  \
# count        38843       38843.000000                    48895.000000
# unique        1764                NaN                             NaN
# top     2019-06-23                NaN                             NaN
# freq          1413                NaN                             NaN
# mean           NaN           1.373221                        7.143982
# std            NaN           1.680442                       32.952519
# min            NaN           0.010000                        1.000000
# 25%            NaN           0.190000                        1.000000
# 50%            NaN           0.720000                        1.000000
# 75%            NaN           2.020000                        2.000000
# max            NaN          58.500000                      327.000000
#
#         availability_365
# count       48895.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean          112.781327
# std           131.622289
# min             0.000000
# 25%             0.000000
# 50%            45.000000
# 75%           227.000000
# max           365.000000

# %%
1 # find which column has nan
df_nan=df.isna().sum()
df_nan
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# First scan the dataframe and requirements. Then decide on few actions before starting the work.
# Columns to use neighbourhood_group,latitude,longitude,room_type,minimum_nights,number_of_reviews,reviews_per_month,calculated_host_listings_count

#1) find missing host name ids and fill the values with host name from other rows
# give numbers to neighbour_group
# price prediction with all regression models linear regression, polynomial, SVR, Random Regressor, Decision Tree Regressor
# # label encoder, convert neighbourhood group into numbers as 0,1,2,3,...use one hot encoding (more than 2 classes, so use one hot encode, no label encoder(label encoder is if data is 1 or 2) )
# 2) first is to fill with zero or
#3) check if the same host id has other properties with reviews per month take mean and fill nans
#not zero or greater than zero, mean of other properties.....

# # 1 lak nan values in reviews_per_month

# first check if num_of_reviews>0 if no fill with zero else find the host_id.
# Find all properties of this host and do mean of reviews_per_month to fill the nan value

# %%
# Filling missing 'host_name' values with the respective 'host_id'
# first, find the nan values of host_name, then find the host_id for that...
#...find that host_id on other rows, get host_name from that host_id and fill that host_name on the respective host id wher host_name is nan

# rows with NaN values in the 'host_name' column
nan_rows = df[df['host_name'].isna()]

# mapping of 'host_id' to 'host_name' for non-NaN values
host_id_to_name_mapping = df.dropna(subset=['host_name']).set_index('host_id')['host_name'].to_dict()

# mapping to fill NaN values in 'host_name' column
df.loc[nan_rows.index, 'host_name'] = nan_rows['host_id'].map(host_id_to_name_mapping)

print(df)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2             NaN                NaN                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# 1) Calculate How many properties in each neighbourhood group

count_properties_in_neighbourhood_group = df.groupby('neighbourhood_group')['id'].nunique()
print(count_properties_in_neighbourhood_group )
# Out:
# neighbourhood_group
# Bronx             1091
# Brooklyn         20104
# Manhattan        21661
# Queens            5666
# Staten Island      373
# Name: id, dtype: int64

# %%
# 2) Which Neighbour Hood Group Has highest prices use bar chart to show this for all neighbourhood groups


group_by_mean = df.groupby('neighbourhood_group')['price'].mean().reset_index()

sorted_groups = group_by_mean.sort_values(by='price', ascending=False)

highest_price_group = sorted_groups.iloc[0]['neighbourhood_group']
highest_price = sorted_groups.iloc[0]['price']

print (sorted_groups)

# Bar chart
plt.figure(figsize=(20, 8))
plt.bar(sorted_groups['neighbourhood_group'], sorted_groups['price'], color='grey')
plt.title('Mean Prices by Neighborhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Mean Price')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

print(highest_price_group, "neighborhood group has the highest mean price of $", highest_price, ".")
# Out:
#   neighbourhood_group       price
# 2           Manhattan  196.875814
# 1            Brooklyn  124.383207
# 4       Staten Island  114.812332
# 3              Queens   99.517649
# 0               Bronx   87.496792
# Manhattan neighborhood group has the highest mean price of $ 196.8758136743456 .

# %%
# 3) Which Neighbourhood group has lowest prices use bar chart to show this for all neighbourhood groups

group_by_mean = df.groupby('neighbourhood_group')['price'].mean().reset_index()

sorted_groups = group_by_mean.sort_values(by='price', ascending=True)

lowest_price_group = sorted_groups.iloc[0]['neighbourhood_group']
lowest_price = sorted_groups.iloc[0]['price']

print (sorted_groups)

# Bar chart
plt.figure(figsize=(20, 8))
plt.bar(sorted_groups['neighbourhood_group'], sorted_groups['price'], color='skyblue')
plt.title('Mean Prices by Neighborhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Mean Price')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

print(lowest_price_group, "neighborhood group has the highest mean price of $", lowest_price, ".")
# Out:
#   neighbourhood_group       price
# 0               Bronx   87.496792
# 3              Queens   99.517649
# 4       Staten Island  114.812332
# 1            Brooklyn  124.383207
# 2           Manhattan  196.875814
# Bronx neighborhood group has the highest mean price of $ 87.4967919340055 .

# %%
# 4) Highest and lowest price airbnb in each Neighbour Hood Group

agg_neighbourhood_group = df.groupby('neighbourhood_group')['price'].agg(['max', 'min'])

agg_neighbourhood_group_in_column = agg_neighbourhood_group.rename(columns={'max': 'Highest_Price', 'min': 'Lowest_Price'})

# Print the result
print(agg_neighbourhood_group_in_column)
# Out:
#                      Highest_Price  Lowest_Price
# neighbourhood_group
# Bronx                         2500             0
# Brooklyn                     10000             0
# Manhattan                    10000             0
# Queens                       10000            10
# Staten Island                 5000            13

# %%
# filling nan values by zero on reviews_per_month

df['reviews_per_month'].fillna(0, inplace=True)

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# check if the same host id has other properties with reviews per month take mean and fill nans


# Group by 'host_id' and calculate the mean of 'reviews_per_month'
mean_reviews_by_host = df.groupby('host_id')['reviews_per_month'].mean()

# Step 2: Create a dictionary mapping 'host_id' to mean 'reviews_per_month'
host_id_to_mean_reviews = mean_reviews_by_host.to_dict()

# Step 3: Use the dictionary to fill NaN values in 'reviews_per_month'
df['reviews_per_month'].fillna(df['host_id'].map(host_id_to_mean_reviews), inplace=True)
# Out:
# None

# %%
# 5) Which Host has highest count of properties

# Group by 'host_id' to count the number of properties for each host
# host_property_counts = df['host_id'].value_counts()
# print (host_property_counts)

# # The host with the highest count of properties
# highest_property_count_host = host_property_counts.idxmax() #finds the host (host ID) with the maximum count of properties and assigns it to the variable highest_property_count_host
# highest_property_count = host_property_counts.max() # returns the maximum value in a Series

# print("Host ID", highest_property_count_host, "has the highest count of properties having", highest_property_count, "properties.")

# Grouping data by 'host_id' and 'neighbourhood', then calculating the count of properties and the mean of 'reviews_per_month'
grouped_data = df.groupby(['host_id', 'neighbourhood']).agg({'neighbourhood': 'count', 'reviews_per_month': 'mean'})

# Renaming the columns for clarity
grouped_data.rename(columns={'neighbourhood': 'property_count', 'reviews_per_month': 'average_reviews_per_month'}, inplace=True)

# the highest count of properties
highest_property_count_host = grouped_data['property_count'].idxmax()

# Count of properties and average reviews per month for the host with the highest properties
highest_property_count = grouped_data.loc[highest_property_count_host]['property_count']
average_reviews_per_month = grouped_data.loc[highest_property_count_host]['average_reviews_per_month']


print("Host ID", highest_property_count_host [0], "has the highest count of properties with", highest_property_count, "counts in",highest_property_count_host [1], "and average reviews per month is ", average_reviews_per_month, '.')
# Out:
# Host ID 219517861 has the highest count of properties with 218.0 counts in Financial District and average reviews per month is  1.625091743119266 .

# %%
# 6) Which neighbourhood is most expensive and cheapest top 10 barchart

neighbourhood_prices = df.groupby('neighbourhood')['price'].mean() # average price for each neighborhood

# Sorting the neighbourhoods by average price in ascending order for cheapest
cheapest_neighbourhoods = neighbourhood_prices.sort_values(ascending=True).head(10)

# Sorting the neighbourhoods by average price in descending order for most expensive
expensive_neighbourhoods = neighbourhood_prices.sort_values(ascending=False).head(10)

# combined DataFrame for plotting
combined_neighbourhoods = pd.concat([cheapest_neighbourhoods, expensive_neighbourhoods])

# bar chart for top 10 cheapest and most expensive neighbourhoods
plt.figure(figsize=(20, 8))
combined_neighbourhoods.plot(kind='bar', color=['green', 'orange'])
plt.title('Top 10 Cheapest and Most Expensive Neighbourhoods')
plt.xlabel('Neighbourhood')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.legend(['Cheapest', 'Most Expensive'])
plt.tight_layout()
plt.show()

# %%
# 7) Count different type of room_type and do a pie chart showing % of each room type in overall dataset

room_type_counts = df['room_type'].value_counts()
print (room_type_counts)

colors = ['green', 'yellow', 'blue', 'orange']

# pie chart
plt.figure(figsize=(10, 8))
plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%', startangle=45, colors=colors)
plt.title('Room Types')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
# 8) scatter plot between longitutude and latitude for different neighbourhood groups

neighbourhood_group_colors = {
    'Bronx': 'blue',
    'Staten Island': 'green',
    'Queens': 'red',
    'Brooklyn': 'orange',
    'Manhattan': 'black',
}

# scatter plots by neighbourhood group
fig, ax = plt.subplots(figsize=(15, 10))

# Loop through each neighborhood group and create a scatter plot
for group, color in neighbourhood_group_colors.items():
    group_data = df[df['neighbourhood_group'] == group]
    ax.scatter(group_data['longitude'], group_data['latitude'], label=group, c=color, alpha=0.5)

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Scatter Plot of Longitude vs. Latitude by Neighborhood Group')
ax.legend()

plt.show()

# %%
# 9) scatter plot between longitutude and latitude for different room_types

room_type_colors = {
    'Shared room': 'blue',
    'Private room': 'green',
    'Entire home/apt': 'red',
}

fig, ax = plt.subplots(figsize=(15, 10))

for group, color in room_type_colors.items():
    group_data = df[df['room_type'] == group]
    ax.scatter(group_data['longitude'], group_data['latitude'], label=group, c=color, alpha=0.5)

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Scatter Plot of Longitude vs. Latitude by Room Type')
ax.legend()

plt.show()

# %%
# 10) room_type vs price bar chart for the mean and highest and lowest

#Using agg to calculate  mean, highest, and lowest prices for each room_type
room_type_agg = df.groupby('room_type')['price'].agg(['mean', 'max', 'min'])

plt.figure(figsize=(20, 8))

room_type_agg.plot(kind='bar', colormap='autumn', alpha=0.7)

plt.title('Room Type vs. Price Statistics')
plt.xlabel('Room Type')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend(['Mean Price', 'Highest Price', 'Lowest Price'])

plt.tight_layout()
plt.show()

# %%
# 11) Do a similar plot to this

#Mapping 'neighbourhood_group' values to group numbers
group_mapping = {
    'Brooklyn': 1,
    'Bronx': 2,
    'Queens': 3,
    'Manhattan': 4,
    'Staten Island': 5
}

df['neighbourhood_group'] = df['neighbourhood_group'].map(group_mapping)

# a pivot table with the modified 'neighbourhood_group' values
pivot_df = df.pivot_table(index='room_type', columns='neighbourhood_group', values='count', aggfunc='count', fill_value=0)

fig, ax = plt.subplots(figsize=(10, 6))

room_types = pivot_df.index

neighbourhood_groups = pivot_df.columns

bottom = [0] * len(neighbourhood_groups)

for room_type in room_types:
    values = pivot_df.loc[room_type]
    ax.bar(neighbourhood_groups, values, label=room_type, bottom=bottom)
    bottom = [bottom[i] + values[i] for i in range(len(neighbourhood_groups))]

plt.title('Count of Neighbourhood Groups in Each Room Type')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Count')
plt.legend(title='Room Type')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-b0b189526daf> in <cell line: 15>()
#      13
#      14 # a pivot table with the modified 'neighbourhood_group' values
# ---> 15 pivot_df = df.pivot_table(index='room_type', columns='neighbourhood_group', values='count', aggfunc='count', fill_value=0)
#      16
#      17 fig, ax = plt.subplots(figsize=(10, 6))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8729         from pandas.core.reshape.pivot import pivot_table
#    8730
# -> 8731         return pivot_table(
#    8732             self,
#    8733             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      95         return table.__finalize__(data, method="pivot_table")
#      96
# ---> 97     table = __internal_pivot_table(
#      98         data,
#      99         values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     141         for i in values:
#     142             if i not in data:
# --> 143                 raise KeyError(i)
#     144
#     145         to_filter = []
#
# KeyError: 'count'
